# %%
import requests as req
from bs4 import BeautifulSoup

# %%
url = "https://pypi.org/project/beautifulsoup4/"
response = req.get(url)
print(response)
# Out:
# <Response [200]>

# %%
raw_html = response.text
raw_html
# Out:
# '\n\n\n\n<!DOCTYPE html>\n<html lang="en" dir="ltr">\n  <head>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1">\n\n    <meta name="defaultLanguage" content="en">\n    <meta name="availableLanguages" content="en, es, fr, ja, pt_BR, uk, el, de, zh_Hans, zh_Hant, ru, he, eo">\n\n\n    <title>beautifulsoup4 · PyPI</title>\n    <meta name="description" content="Screen-scraping library">\n\n    <link rel="stylesheet" href="/static/css/warehouse-ltr.6d3ae9c8.css">\n    <link rel="stylesheet" href="/static/css/fontawesome.da0464c1.css">\n    <link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Source+Sans+3:400,400italic,600,600italic,700,700italic%7CSource+Code+Pro:500">\n    <noscript>\n      <link rel="stylesheet" href="/static/css/noscript.0673c9ea.css">\n    </noscript>\n\n\n    <link rel="icon" href="/static/images/favicon.35549fe8.ico" type="image/x-icon">\n\
# ...

# %%
beauty_html = BeautifulSoup(raw_html, "html.parser")
beauty_html
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="en" name="defaultLanguage"/>
# <meta content="en, es, fr, ja, pt_BR, uk, el, de, zh_Hans, zh_Hant, ru, he, eo" name="availableLanguages"/>
# <title>beautifulsoup4 · PyPI</title>
# <meta content="Screen-scraping library" name="description"/>
# <link href="/static/css/warehouse-ltr.6d3ae9c8.css" rel="stylesheet"/>
# <link href="/static/css/fontawesome.da0464c1.css" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Source+Sans+3:400,400italic,600,600italic,700,700italic%7CSource+Code+Pro:500" rel="stylesheet"/>
# <noscript>
# <link href="/static/css/noscript.0673c9ea.css" rel="stylesheet"/>
# </noscript>
# <link href="/static/images/favicon.35549fe8.ico" rel="icon" type="image/x-icon"/>
# ...

# %%
beauty_html.title
# Out:
# <title>beautifulsoup4 · PyPI</title>

# %%
beauty_html.title.title

# %%
beauty_html.h1
# Out:
# <h1 class="package-header__name">
#         beautifulsoup4 4.12.3
#       </h1>

# %%
beauty_html.h1.string
# Out:
# '\n        beautifulsoup4 4.12.3\n      '

# %%
beauty_html.nav
# Out:
# <nav aria-label="Main navigation" class="horizontal-menu horizontal-menu--light horizontal-menu--tall hide-on-tablet">
# <ul>
# <li class="horizontal-menu__item"><a class="horizontal-menu__link" href="/help/">Help</a></li>
# <li class="horizontal-menu__item"><a class="horizontal-menu__link" href="/sponsors/">Sponsors</a></li>
# <li class="horizontal-menu__item"><a class="horizontal-menu__link" href="/account/login/">Log in</a></li>
# <li class="horizontal-menu__item"><a class="horizontal-menu__link" href="/account/register/">Register</a></li>
# </ul>
# </nav>

# %%
h2 = beauty_html.find_all('h2')
h2
# Out:
# [<h2 class="page-title">Project description</h2>,
#  <h2 class="page-title">Project details</h2>,
#  <h2 class="page-title split-layout">
#  <span>Release history</span>
#  <span class="reset-text margin-top">
#  <a href="/help/#project-release-notifications">Release notifications</a> |
#                <a href="/rss/project/beautifulsoup4/releases.xml">RSS feed <i aria-hidden="true" class="fa fa-rss"></i></a>
#  </span>
#  </h2>,
#  <h2 class="page-title">Download files</h2>,
#  <h2>Help</h2>,
#  <h2>About PyPI</h2>,
#  <h2>Contributing to PyPI</h2>,
#  <h2>Using PyPI</h2>]

# %%
anchor = beauty_html.find_all('a')
anchor
# Out:
# [<a class="skip-to-content" href="#content">Skip to main content</a>,
#  <a class="site-header__logo" href="/">
#  <img alt="PyPI" src="/static/images/logo-small.8998e9d1.svg"/>
#  </a>,
#  <a class="horizontal-menu__link" href="/help/">Help</a>,
#  <a class="horizontal-menu__link" href="/sponsors/">Sponsors</a>,
#  <a class="horizontal-menu__link" href="/account/login/">Log in</a>,
#  <a class="horizontal-menu__link" href="/account/register/">Register</a>,
#  <a class="dropdown__link" href="/help/">Help</a>,
#  <a class="dropdown__link" href="/sponsors/">Sponsors</a>,
#  <a class="dropdown__link" href="/account/login/">Log in</a>,
#  <a class="dropdown__link" href="/account/register/">Register</a>,
#  <a class="status-badge status-badge--good" href="/project/beautifulsoup4/">
#  <span>Latest version</span>
#  </a>,
# ...

# %%
for a in anchor:
    print(a)
# Out:
# <a class="skip-to-content" href="#content">Skip to main content</a>
# <a class="site-header__logo" href="/">
# <img alt="PyPI" src="/static/images/logo-small.8998e9d1.svg"/>
# </a>
# <a class="horizontal-menu__link" href="/help/">Help</a>
# <a class="horizontal-menu__link" href="/sponsors/">Sponsors</a>
# <a class="horizontal-menu__link" href="/account/login/">Log in</a>
# <a class="horizontal-menu__link" href="/account/register/">Register</a>
# <a class="dropdown__link" href="/help/">Help</a>
# <a class="dropdown__link" href="/sponsors/">Sponsors</a>
# <a class="dropdown__link" href="/account/login/">Log in</a>
# <a class="dropdown__link" href="/account/register/">Register</a>
# <a class="status-badge status-badge--good" href="/project/beautifulsoup4/">
# <span>Latest version</span>
# </a>
# ...

# %%
footer = beauty_html.find_all(class_= "footer")
footer
# Out:
# [<footer class="footer">
#  <div class="footer__logo">
#  <img alt="" class="-js-white-cube" src="/static/images/white-cube.2351a86c.svg"/>
#  </div>
#  <div class="footer__menus">
#  <div class="footer__menu">
#  <h2>Help</h2>
#  <nav aria-label="Help navigation">
#  <ul>
#  <li><a href="https://packaging.python.org/tutorials/installing-packages/" rel="noopener" target="_blank" title="External link">Installing packages</a></li>
#  <li><a href="https://packaging.python.org/tutorials/packaging-projects/" rel="noopener" target="_blank" title="External link">Uploading packages</a></li>
#  <li><a href="https://packaging.python.org/" rel="noopener" target="_blank" title="External link">User guide</a></li>
#  <li><a href="https://www.python.org/dev/peps/pep-0541/" rel="noopener" target="_blank" title="External link">Project name retention</a></li>
#  <li><a href="/help/">FAQs</a></li>
#  </ul>
#  </nav>
#  </div>
#  <div class="footer__menu">
#  <h2>About PyPI</h2>
# ...
